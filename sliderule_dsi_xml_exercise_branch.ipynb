# %% [markdown]
# # XML example and exercise
# ****
# + study examples of accessing nodes in XML tree structure
# + work on exercise to be completed and submitted
# ****
# + reference: https://docs.python.org/2.7/library/xml.etree.elementtree.html
# + data source: http://www.dbis.informatik.uni-goettingen.de/Mondial
# ****

# %%
from xml.etree import ElementTree as ET

# %% [markdown]
# ## XML example
#
# + for details about tree traversal and iterators, see https://docs.python.org/2.7/library/xml.etree.elementtree.html

# %%
document_tree = ET.parse( './data/mondial_database_less.xml' )

# %%
# print names of all countries
for child in document_tree.getroot():
    print child.find('name').text
# Out:
# Albania
# Greece
# Macedonia
# Serbia
# Montenegro
# Kosovo
# Andorra

# %%
# print names of all countries and their cities
for element in document_tree.iterfind('country'):
    print '* ' + element.find('name').text + ':',
    capitals_string = ''
    for subelement in element.getiterator('city'):
        capitals_string += subelement.find('name').text + ', '
    print capitals_string[:-2]
# Out:
# * Albania: Tirana, Shkodër, Durrës, Vlorë, Elbasan, Korçë
# * Greece: Komotini, Kavala, Athina, Peiraias, Peristeri, Acharnes, Patra, Kozani, Kerkyra, Ioannina, Thessaloniki, Iraklio, Chania, Ermoupoli, Rhodes, Tripoli, Lamia, Chalkida, Larissa, Volos, Mytilini, Karyes
# * Macedonia: Skopje, Kumanovo
# * Serbia: Beograd, Novi Sad, Niš
# * Montenegro: Podgorica
# * Kosovo: Prishtine
# * Andorra: Andorra la Vella

# %% [markdown]
# ****
# ## XML exercise
#
# Using data in 'data/mondial_database.xml', the examples above, and refering to https://docs.python.org/2.7/library/xml.etree.elementtree.html, find
#
# 1. 10 countries with the lowest infant mortality rates
# 2. 10 cities with the largest population
# 3. 10 ethnic groups with the largest overall populations (sum of best/latest estimates over all countries)
# 4. name and country of a) longest river, b) largest lake and c) airport at highest elevation

# %%
import pandas as pd

# %%
document = ET.parse( './data/mondial_database.xml' )

# %%
# Build disctionary containing country name, infant mortality
# Also creaite dict to translate country codes to names
country_mortality={}
country_code={}
for child in document.getroot().iterfind('country[infant_mortality]'):
    c_code = child.attrib["car_code"]
    c_name = child.find('name').text
    country_code.update({c_code:c_name})
    country_mortality.update({c_name: float(child.find('infant_mortality').text)})

# %%
# Convert dict to DataFrame, sort by mortality rate and output 10 countries with lowest mortality rate
country_mortality_f = pd.DataFrame.from_dict(country_mortality, orient='index').sort_values(by=[0], ascending=True).head(10)
country_mortality_f
# Out:
#                    0
# Monaco          1.81
# Japan           2.13
# Bermuda         2.48
# Norway          2.48
# Singapore       2.53
# Sweden          2.60
# Czech Republic  2.63
# Hong Kong       2.73
# Macao           3.13
# Iceland         3.15

# %%
# Build dictionary containing city name, population estimate and date of population estimate
city_size={}
for child in document.getroot().iterfind('country'):
    for subelement in child.findall('.//city'):
        city_size.update({subelement.find('name').text:{'population':0,'year':0}})
        for subelement2 in subelement.findall('population'):
            # Different cities have different census / estimate dates
            # In all cases most recent estimates are last, so replace entries until final estimate is reached
            # In third excercise started using commands to go directly to last population size element
            city_size[subelement.find('name').text]['year']= subelement2.attrib["year"]
            city_size[subelement.find('name').text]['population'] = int(subelement2.text)

# %%
# Convert dict to DataFrame, sort by population and output top 10 cities by population
city_size_f = pd.DataFrame.from_dict(city_size, orient='index').sort_values(by=["population"], ascending=False).head(10)
city_size_f
# Out:
#            year  population
# Shanghai   2010    22315474
# Istanbul   2012    13710512
# Mumbai     2011    12442373
# Moskva     2013    11979529
# Beijing    2010    11716620
# São Paulo  2010    11152344
# Tianjin    2010    11090314
# Guangzhou  2010    11071424
# Delhi      2011    11034555
# Shenzhen   2010    10358381

# %%
# Build dictionary containing country name, population estimate and ethnic groups
c_ethnic={}
for child in document.getroot().iterfind('country'):
    c_name = child.find('name').text
    popul = float(child.findall("population[last()]")[0].text)
    c_ethnic.update({c_name:{"Total_Population":popul}})
    for subelement in child.findall(".ethnicgroup"):
        ethnic_name = subelement.text
        ethnic_popul = float(subelement.attrib["percentage"])*popul/100.0
        c_ethnic[child.find('name').text].update({ethnic_name:ethnic_popul})
c_ethnic
# Out:
# {'Afghanistan': {'Hazara': 4944389.0,
#   'Pashtun': 9888778.0,
#   'Tajik': 6505775.0,
#   'Total_Population': 26023100.0,
#   'Uzbek': 1561386.0},
#  'Albania': {'Albanian': 2660131.1,
#   'Greek': 84004.14,
#   'Total_Population': 2800138.0},
#  'Algeria': {'Arab-Berber': 36692191.8,
#   'European': 370628.2,
#   'Total_Population': 37062820.0},
#  'American Samoa': {'Caucasian': 1110.38,
#   'Samoan': 49411.91,
#   'Tongan': 2220.76,
#   'Total_Population': 55519.0},
#  'Andorra': {'African': 3905.75,
#   'Andorran': 25777.95,
#   'French': 1562.3,
#   'Portuguese': 8592.65,
#   'Spanish': 33589.45,
#   'Total_Population': 78115.0},
#  'Angola': {'Bakongo': 3169829.13,
#   'European': 243833.01,
#   'Kimbundu': 6095825.25,
#   'Ovimbundu': 9021821.37,
#   'Total_Population': 24383301.0},
#  'Anguilla': {'Black': 11746.337,
#   'Mulatto': 599.702,
#   'Total_Population': 13037.0,
#   'White': 482.369},
#  'Antigua and Barbuda': {'Total_Population': 81799.0},
#  'Argentina': {'European': 41389415.0, 'Total_Population': 42669500.0},
#  'Armenia': {'Armenian': 2957260.7830000003,
#   'Russian': 15134.395,
#   'Total_Population': 3026879.0,
#   'Yezidi': 39349.427},
#  'Aruba': {'European/Caribbean Amerindian': 81187.2,
#   'Total_Population': 101484.0},
#  'Australia': {'Asian': 1619469.67,
#   'European': 21284458.52,
#   'Total_Population': 23135281.0},
#  'Austria': {'Austrian': 7743280.449,
#   'Croat': 169995.18,
#   'German': 76497.831,
#   'Serbs': 169995.18,
#   'Slovene': 84997.59,
#   'Total_Population': 8499759.0,
#   'Turkish': 135996.144},
#  'Azerbaijan': {'Armenian': 140347.5,
#   'Azeri': 8476989.0,
#   'Dagestani': 205843.0,
#   'Russian': 168417.0,
#   'Total_Population': 9356500.0},
#  'Bahamas': {'Total_Population': 353658.0},
#  'Bahrain': {'Arab': 123459.6,
#   'Asian': 160497.48,
#   'Bahraini': 777795.48,
#   'Iranian': 98767.68,
#   'Total_Population': 1234596.0},
#  'Bangladesh': {'Bengali': 146776916.72, 'Total_Population': 149772364.0},
#  'Barbados': {'African': 222256.8,
#   'European': 11112.84,
#   'Total_Population': 277821.0},
#  'Belarus': {'Belorussian': 7682081.904,
#   'Polish': 368966.98799999995,
#   'Russian': 1078518.888,
#   'Total_Population': 9460692.0,
#   'Ukrainian': 227056.608},
#  'Belgium': {'Fleming': 6437741.32,
#   'Total_Population': 11099554.0,
#   'Walloon': 3440861.74},
#  'Belize': {'Creole': 77929.779,
#   'Garifuna': 19091.231,
#   'Maya': 33174.926,
#   'Mestizo': 152416.877,
#   'Total_Population': 312971.0},
#  'Benin': {'African': 9884045.16, 'Total_Population': 9983884.0},
#  'Bermuda': {'Black': 34687.98,
#   'Mixed': 4111.168000000001,
#   'Total_Population': 64237.0,
#   'White': 21904.817000000003},
#  'Bhutan': {'Bhote': 366502.0,
#   'Nepalese': 256551.4,
#   'Total_Population': 733004.0},
#  'Bolivia': {'Aymara': 2506815.5,
#   'European': 1504089.3,
#   'Mestizo': 3008178.6,
#   'Quechua': 3008178.6,
#   'Total_Population': 10027262.0},
#  'Bosnia and Herzegovina': {'Bosniak': 1406691.762,
#   'Croat': 542201.946,
#   'Muslim': 1819978.56,
#   'Total_Population': 3791622.0},
#  'Botswana': {'Batswana': 1936316.6,
#   'Kgalagadi': 81529.12,
#   'Total_Population': 2038228.0},
#  'Brazil': {'African': 12571650.844,
#   'European': 108886717.79400001,
#   'Mulatto': 78065896.37,
#   'Total_Population': 202768562.0},
#  'British Virgin Islands': {'Amerindian': 787.4739999999999,
#   'Black': 19316.274,
#   'Mixed': 1250.6940000000002,
#   'Total_Population': 23161.0,
#   'White': 1621.27},
#  'Brunei': {'Chinese': 78674.4,
#   'Malay': 251758.08,
#   'Total_Population': 393372.0},
#  'Bulgaria': {'Armenian': 21853.656000000003,
#   'Bulgarian': 5601820.488000001,
#   'Macedonian': 182113.8,
#   'Roma': 320520.288,
#   'Russian': 14569.104000000001,
#   'Total_Population': 7284552.0,
#   'Turkish': 582764.16},
#  'Burkina Faso': {'Mossi': 4157471.04, 'Total_Population': 17322796.0},
#  'Burundi': {'Total_Population': 8444784.0},
#  'Cambodia': {'Chinese': 143649.31,
#   'Khmer': 12928437.9,
#   'Total_Population': 14364931.0,
#   'Vietnamese': 718246.55},
#  'Cameroon': {'African': 2522793.0,
#   'Cameroon Highlanders': 6015891.0,
#   'Eastern Nigritic': 1358427.0,
#   'Equatorial Bantu': 3687159.0,
#   'Fulani': 1940610.0,
#   'Kirdi': 2134671.0,
#   'Northwestern Bantu': 1552488.0,
#   'Total_Population': 19406100.0},
#  'Canada': {'British Isles': 9844325.12,
#   'European': 5273745.6,
#   'French': 8086409.92,
#   'Inuit': 703166.08,
#   'Total_Population': 35158304.0},
#  'Cape Verde': {'African': 137725.0,
#   'Creole': 349231.25,
#   'European': 4918.75,
#   'Total_Population': 491875.0},
#  'Cayman Islands': {'Black': 11138.2,
#   'Mixed': 22276.4,
#   'Total_Population': 55691.0,
#   'White': 11138.2},
#  'Central African Republic': {'Banda': 1174478.67,
#   'Baya': 1478973.14,
#   'MBaka': 173996.84,
#   'Mandjia': 913483.41,
#   'Mboum': 173996.84,
#   'Sara': 434992.1,
#   'Total_Population': 4349921.0},
#  'Ceuta': {'Total_Population': 82376.0},
#  'Chad': {'Total_Population': 11720781.0},
#  'Chile': {'Amerindian': 490257.87,
#   'European': 15524832.55,
#   'Total_Population': 16341929.0},
#  'China': {'Han Chinese': 1245058800.0, 'Total_Population': 1360720000.0},
#  'Christmas Island': {'Chinese': 1450.4,
#   'European': 414.4,
#   'Malay': 207.2,
#   'Total_Population': 2072.0},
#  'Cocos Islands': {'Total_Population': 596.0},
#  'Colombia': {'African': 1906471.48,
#   'Amerindian': 476617.87,
#   'European': 9532357.4,
#   'Mestizo': 27643836.46,
#   'Mulatto': 6672650.18,
#   'Total_Population': 47661787.0,
#   'black-Amerindian': 1429853.61},
#  'Comoros': {'Total_Population': 683081.0},
#  'Congo': {'Total_Population': 4001831.0},
#  'Cook Islands': {'Polynesian': 16637.39, 'Total_Population': 17794.0},
#  'Costa Rica': {'African': 143193.57,
#   'Amerindian': 47731.19,
#   'Chinese': 47731.19,
#   'European': 954623.8,
#   'Mestizo': 3532108.06,
#   'Total_Population': 4773119.0},
#  'Cote dIvoire': {'Baoule': 5214406.13,
#   'Bete': 4080839.58,
#   'Malinke': 2493846.41,
#   'Senoufou': 3400699.65,
#   'Total_Population': 22671331.0},
#  'Croatia': {'Croat': 3844388.352,
#   'Hungarian': 21453.06,
#   'Muslim': 38615.508,
#   'Serb': 193077.54,
#   'Slovene': 21453.06,
#   'Total_Population': 4290612.0},
#  'Cuba': {'African': 1127899.825,
#   'European': 7269928.574999999,
#   'Mestizo': 1340079.0,
#   'Mulatto': 1340079.0,
#   'Total_Population': 11167325.0},
#  'Curacao': {'Total_Population': 150563.0},
#  'Cyprus': {'Greek': 647113.39,
#   'Total_Population': 840407.0,
#   'Turkish': 151273.26},
#  'Czech Republic': {'Czech': 9548241.456,
#   'German': 52811.07,
#   'Hungarian': 21124.428000000004,
#   'Moravian': 390801.91800000006,
#   'Polish': 63373.28399999999,
#   'Roma': 31686.641999999996,
#   'Slovak': 200682.066,
#   'Total_Population': 10562214.0},
#  'Denmark': {'Total_Population': 5580516.0},
#  'Djibouti': {'Afar': 291912.6,
#   'Italian': 41701.8,
#   'Somali': 500421.6,
#   'Total_Population': 834036.0},
#  'Dominica': {'Carib Indians': 70739.0, 'Total_Population': 70739.0},
#  'Dominican Republic': {'African': 1038980.91,
#   'European': 1511244.96,
#   'Mulatto': 6895055.13,
#   'Total_Population': 9445281.0},
#  'Ecuador': {'African': 434504.97,
#   'Amerindian': 3620874.75,
#   'European': 1013844.93,
#   'Mestizo': 9414274.35,
#   'Total_Population': 14483499.0},
#  'Egypt': {'Eastern Hamitic': 82830376.53,
#   'European': 836670.47,
#   'Total_Population': 83667047.0},
#  'El Salvador': {'Amerindian': 62904.2,
#   'European': 566137.8,
#   'Mestizo': 5661378.0,
#   'Total_Population': 6290420.0},
#  'Equatorial Guinea': {'Total_Population': 696167.0},
#  'Eritrea': {'Bilen': 114823.18,
#   'Kunama': 114823.18,
#   'Rashaida': 114823.18,
#   'Saho': 229646.36,
#   'Tigre': 1722347.7,
#   'Tigrinya': 3157637.45,
#   'Total_Population': 5741159.0},
#  'Estonia': {'Belorussian': 15533.46,
#   'Estonian': 889290.585,
#   'Finn': 10355.64,
#   'Russian': 331380.48,
#   'Total_Population': 1294455.0,
#   'Ukrainian': 27183.555},
#  'Ethiopia': {'Afar': 1433456.779,
#   'Amhara': 22682345.503,
#   'Gurage': 2108024.675,
#   'Hadiya': 1433456.779,
#   'Oromo': 29090740.515,
#   'Sidama': 3372839.48,
#   'Somali': 5227901.194,
#   'Tigraway': 5143580.2069999995,
#   'Total_Population': 84320987.0,
#   'Welaita': 1939382.701},
#  'Falkland Islands': {'Christian': 1969.632,
#   'None': 923.265,
#   'Total_Population': 2931.0},
#  'Faroe Islands': {'Scandinavian': 48197.0, 'Total_Population': 48197.0},
#  'Fiji': {'Fijian': 421673.91,
#   'Indian': 395857.14,
#   'Total_Population': 860559.0},
#  'Finland': {'Estonian': 16365.204,
#   'Finn': 5095033.512,
#   'Russian': 27275.34,
#   'Swede': 305483.80799999996,
#   'Total_Population': 5455068.0},
#  'France': {'Total_Population': 64933400.0},
#  'French Guiana': {'Amerindian': 28505.88, 'Total_Population': 237549.0},
#  'French Polynesia': {'Chinese': 32192.4,
#   'French': 26827.0,
#   'Polynesian': 209250.6,
#   'Total_Population': 268270.0},
#  'Gabon': {'Total_Population': 1556222.0},
#  'Gambia': {'African': 1863625.5, 'Total_Population': 1882450.0},
#  'Gaza Strip': {'Jewish': 10560.222,
#   'Palestinian Arab': 1749476.7780000002,
#   'Total_Population': 1760037.0},
#  'Georgia': {'Azeri': 291447.0,
#   'Georgian': 3757424.4,
#   'Russian': 67257.0,
#   'Total_Population': 4483800.0},
#  'Germany': {'German': 73401020.925,
#   'Total_Population': 80219695.0,
#   'Turkish': 1925272.68},
#  'Ghana': {'African': 24609505.354000002,
#   'European': 49317.64600000001,
#   'Total_Population': 24658823.0},
#  'Gibraltar': {'Total_Population': 27495.0},
#  'Greece': {'Greek': 10059145.98, 'Total_Population': 10816286.0},
#  'Greenland': {'Danish': 7891.8,
#   'Greenlander': 48478.2,
#   'Total_Population': 56370.0},
#  'Grenada': {'African': 103328.0, 'Total_Population': 103328.0},
#  'Guadeloupe': {'Chinese': 20231.75, 'Total_Population': 404635.0},
#  'Guam': {'Chamorro': 59121.818,
#   'Filipino': 41911.154,
#   'Total_Population': 159358.0},
#  'Guatemala': {'Amerindian': 4597379.375,
#   'European': 1507337.5,
#   'Mestizo': 7536687.5,
#   'Total_Population': 15073375.0},
#  'Guernsey': {'Norman-French': 59807.0, 'Total_Population': 59807.0},
#  'Guinea': {'Malinke': 3188691.6,
#   'Peuhl': 4251588.8,
#   'Soussou': 2125794.4,
#   'Total_Population': 10628972.0},
#  'Guinea-Bissau': {'African': 1570757.76,
#   'European': 15866.24,
#   'Total_Population': 1586624.0},
#  'Guyana': {'African': 225860.968,
#   'Amerindian': 68057.44399999999,
#   'East Indian': 325329.54,
#   'Total_Population': 747884.0},
#  'Haiti': {'African': 9401580.0,
#   'European': 197928.0,
#   'Mulatto': 296892.0,
#   'Total_Population': 9896400.0},
#  'Holy See': {'Total_Population': 842.0},
#  'Honduras': {'African': 160919.8,
#   'Amerindian': 563219.3,
#   'European': 80459.9,
#   'Mestizo': 7241391.0,
#   'Total_Population': 8045990.0},
#  'Hong Kong': {'Chinese': 6717997.2,
#   'Filipino': 113145.21600000001,
#   'Indonesian': 91930.48800000001,
#   'Total_Population': 7071576.0},
#  'Hungary': {'German': 258378.328,
#   'Hungarian': 9172430.644,
#   'Roma': 188814.932,
#   'Romanian': 69563.396,
#   'Serb': 198752.56,
#   'Slovak': 79501.024,
#   'Total_Population': 9937628.0},
#  'Iceland': {'Celt': 318452.0, 'Total_Population': 318452.0},
#  'India': {'Dravidian': 302713744.25,
#   'Indo-Aryan': 871815583.44,
#   'Mongol': 36325649.31,
#   'Total_Population': 1210854977.0},
#  'Indonesia': {'Javanese': 113456006.1,
#   'Madurese': 18909334.35,
#   'Malay': 18909334.35,
#   'Sundanese': 35297424.12,
#   'Total_Population': 252124458.0},
#  'Iran': {'Arab': 2254490.07,
#   'Azerbaijani': 18035920.56,
#   'Baloch': 1502993.38,
#   'Gilaki Mazandarani': 6011973.52,
#   'Kurd': 5260476.83,
#   'Lur': 1502993.38,
#   'Persian': 38326331.19,
#   'Total_Population': 75149669.0,
#   'Turkmen': 1502993.38},
#  'Iraq': {'Arab': 24997884.0,
#   'Assyrian': 1666525.6,
#   'Kurdish': 4999576.8,
#   'Total_Population': 33330512.0},
#  'Ireland': {'African': 50470.772000000004,
#   'Asian': 59647.276000000005,
#   'Irish': 4010132.248,
#   'Total_Population': 4588252.0},
#  'Isle of Man': {'Total_Population': 84497.0},
#  'Israel': {'Arab': 1706684.64,
#   'Jewish': 5669161.152000001,
#   'Total_Population': 7420368.0},
#  'Italy': {'Total_Population': 59433744.0},
#  'Jamaica': {'African': 2058561.029,
#   'Afro-Chinese': 32375.796000000002,
#   'Afro-East Indian': 80939.49,
#   'Afro-European': 407395.43299999996,
#   'Total_Population': 2697983.0},
#  'Japan': {'Japanese': 126534212.0, 'Total_Population': 127298000.0},
#  'Jersey': {'Norman-French': 97857.0, 'Total_Population': 97857.0},
#  'Jordan': {'Arab': 6124020.0,
#   'Armenian': 62490.0,
#   'Circassian': 62490.0,
#   'Total_Population': 6249000.0},
#  'Kazakhstan': {'German': 188817.62900000002,
#   'Kazakh': 10831265.809,
#   'Russian': 4068161.643,
#   'Tatar': 223148.107,
#   'Total_Population': 17165239.0,
#   'Uighur': 240313.346,
#   'Ukrainian': 360470.019,
#   'Uzbek': 480626.692},
#  'Kenya': {'Arab': 409091.94,
#   'Kalenjin': 4909103.28,
#   'Kamba': 4500011.34,
#   'Kikuyu': 9000022.68,
#   'Kisii': 2454551.64,
#   'Luhya': 5727287.16,
#   'Luo': 5318195.22,
#   'Meru': 2454551.64,
#   'Total_Population': 40909194.0},
#  'Kiribati': {'Micronesian': 103058.0, 'Total_Population': 103058.0},
#  'Kosovo': {'Albanian': 1595162.24,
#   'Serbian': 86693.6,
#   'Total_Population': 1733872.0},
#  'Kuwait': {'Arab': 1047053.0,
#   'Iranian': 119663.2,
#   'Kuwaiti': 1346211.0,
#   'South Asian': 269242.2,
#   'Total_Population': 2991580.0},
#  'Kyrgyzstan': {'Dungan': 63542.600000000006,
#   'Kyrgyz': 3749013.4000000004,
#   'Russian': 722075.0,
#   'Total_Population': 5776600.0,
#   'Uighur': 57766.0,
#   'Ukrainian': 57766.0,
#   'Uzbek': 797170.8},
#  'Laos': {'Lao Loum': 4429813.76,
#   'Lao Soung Hmong Yao': 586298.88,
#   'Lao Theung': 1433175.04,
#   'Total_Population': 6514432.0,
#   'Vietnamese/Chinese': 65144.32},
#  'Latvia': {'Belorussian': 79243.05600000001,
#   'Latvian': 1305309.228,
#   'Lithuanian': 28615.548000000003,
#   'Polish': 52828.704,
#   'Russian': 611932.488,
#   'Total_Population': 2201196.0,
#   'Ukrainian': 55029.9},
#  'Lebanon': {'Arab': 4124037.4,
#   'Armenian': 173643.68,
#   'Total_Population': 4341092.0},
#  'Lesotho': {'Sotho': 2002894.2370000002, 'Total_Population': 2008921.0},
#  'Liberia': {'African': 3760090.5,
#   'Americo-Liberians': 197899.5,
#   'Total_Population': 3957990.0},
#  'Libya': {'Berber Arab': 5859393.64, 'Total_Population': 6040612.0},
#  'Liechtenstein': {'Alemannic': 34804.2,
#   'Italian': 1831.8,
#   'Total_Population': 36636.0},
#  'Lithuania': {'Belorussian': 32772.41,
#   'Lithuanian': 2502620.4,
#   'Polish': 181737.91,
#   'Russian': 145986.19000000003,
#   'Total_Population': 2979310.0},
#  'Luxembourg': {'French': 23618.385,
#   'German': 12071.618999999999,
#   'Italian': 22568.679,
#   'Luxembourgish': 331182.243,
#   'Portuguese': 69805.44900000001,
#   'Total_Population': 524853.0},
#  'Macao': {'Chinese': 524877.85,
#   'Portuguese': 16575.09,
#   'Total_Population': 552503.0},
#  'Macedonia': {'Albanian': 519068.088,
#   'Gypsy': 55614.43800000001,
#   'Macedonian': 1322387.7480000001,
#   'Serb': 37076.292,
#   'Total_Population': 2059794.0,
#   'Turkish': 80331.966},
#  'Madagascar': {'Total_Population': 21842167.0},
#  'Malawi': {'Total_Population': 15013694.0},
#  'Malaysia': {'Borneo indigenous': 3032240.31,
#   'Chinese': 6533099.577,
#   'Indian': 1957173.291,
#   'Malay': 13893173.783999998,
#   'Total_Population': 27565821.0},
#  'Maldives': {'Total_Population': 341256.0},
#  'Mali': {'Mande': 6992980.5,
#   'Peuhl': 2377613.37,
#   'Songhai': 839157.66,
#   'Total_Population': 13985961.0,
#   'Tuareg': 1398596.1,
#   'Voltaic': 1678315.32},
#  'Malta': {'Total_Population': 417432.0},
#  'Marshall Islands': {'Micronesian': 53158.0, 'Total_Population': 53158.0},
#  'Martinique': {'African-white-Indian': 353061.9,
#   'Chinese': 19614.55,
#   'Total_Population': 392291.0},
#  'Mauritania': {'Black Maur': 1414947.2,
#   'Maur': 1061210.4,
#   'Total_Population': 3537368.0},
#  'Mauritius': {'Creole': 334014.57,
#   'Franco-Mauritian': 24741.82,
#   'Indo-Mauritian': 841221.88,
#   'Sino-Mauritian': 37112.73,
#   'Total_Population': 1237091.0},
#  'Mayotte': {'Total_Population': 212645.0},
#  'Melilla': {'Total_Population': 78476.0},
#  'Mexico': {'Amerindian': 33700961.4,
#   'European': 10110288.42,
#   'Mestizo': 67401922.8,
#   'Total_Population': 112336538.0},
#  'Micronesia': {'Polynesian': 102843.0, 'Total_Population': 102843.0},
#  'Moldova': {'Bulgarian': 67631.279,
#   'Gagauz': 156619.804,
#   'Moldavian/Romanian': 2783561.062,
#   'Russian': 206453.378,
#   'Total_Population': 3559541.0,
#   'Ukrainian': 299001.444},
#  'Monaco': {'French': 17317.15,
#   'Italian': 7000.55,
#   'Monegasque': 7958.52,
#   'Total_Population': 36845.0},
#  'Mongolia': {'Kazak': 137734.25,
#   'Mongol': 2614196.0650000004,
#   'Total_Population': 2754685.0},
#  'Montenegro': {'Albanian': 31001.45,
#   'Bosniak': 49602.32,
#   'Montenegrin': 266612.47,
#   'Serb': 198409.28,
#   'Total_Population': 620029.0},
#  'Montserrat': {'Total_Population': 4922.0},
#  'Morocco': {'Arab-Berber': 32605507.402,
#   'Jewish': 65803.244,
#   'Total_Population': 32901622.0},
#  'Mozambique': {'Euro-African': 47401.43,
#   'European': 14220.428999999998,
#   'Indian': 18960.572,
#   'Total_Population': 23700715.0},
#  'Myanmar': {'Burman': 34965205.6,
#   'Chinese': 1542582.6,
#   'Indian': 1028388.4,
#   'Karen': 3599359.4,
#   'Mon': 1028388.4,
#   'Rakhine': 2056776.8,
#   'Shan': 4627747.8,
#   'Total_Population': 51419420.0},
#  'Namibia': {'Total_Population': 2113077.0},
#  'Nauru': {'Chinese': 802.0,
#   'European': 802.0,
#   'Nauruan': 5814.5,
#   'Pacific Islander': 2606.5,
#   'Total_Population': 10025.0},
#  'Nepal': {'Total_Population': 26494504.0},
#  'Netherlands': {'Caribbean': 134745.448,
#   'Dutch': 13592447.067,
#   'Indonesian': 404236.344,
#   'Moroccan': 336863.62,
#   'Surinamese': 336863.62,
#   'Total_Population': 16843181.0,
#   'Turkish': 370549.982},
#  'New Caledonia': {'European': 83742.78,
#   'Indonesian': 6139.5,
#   'Melanesian': 108300.78,
#   'Total_Population': 245580.0,
#   'Vietnamese': 3438.12,
#   'Wallisian': 22102.2},
#  'New Zealand': {'Asian': 339363.84,
#   'European': 2409483.264,
#   'Maori': 313911.552,
#   'Pacific Islander': 195134.20799999998,
#   'Total_Population': 4242048.0},
#  'Nicaragua': {'African': 546394.05,
#   'Amerindian': 303552.25,
#   'European': 1032077.65,
#   'Mestizo': 4189021.05,
#   'Total_Population': 6071045.0},
#  'Niger': {'Beri Beri': 736964.401,
#   'Djerma': 3770515.54,
#   'Fula': 1456790.095,
#   'Gourmantche': 205664.484,
#   'Hausa': 9597675.92,
#   'Total_Population': 17138707.0,
#   'Tuareg': 1371096.56},
#  'Nigeria': {'African': 162651570.84, 'Total_Population': 164294516.0},
#  'Niue': {'Polynesian': 1611.0, 'Total_Population': 1611.0},
#  'Norfolk Island': {'Total_Population': 2169.0},
#  'North Korea': {'Total_Population': 24500520.0},
#  'Northern Mariana Islands': {'Asian': 30336.129,
#   'Caucasian': 969.8940000000001,
#   'Pacific Islander': 19559.529,
#   'Total_Population': 53883.0},
#  'Norway': {'Norwegian': 4167301.875,
#   'Sami': 75769.125,
#   'Total_Population': 5051275.0},
#  'Oman': {'Total_Population': 3623001.0},
#  'Pakistan': {'Total_Population': 173149306.0},
#  'Palau': {'Total_Population': 17501.0},
#  'Panama': {'Amerindian': 204348.78,
#   'European': 340581.3,
#   'Mestizo': 2860882.92,
#   'Total_Population': 3405813.0},
#  'Papua New Guinea': {'Total_Population': 7275324.0},
#  'Paraguay': {'Mestizo': 6338999.45, 'Total_Population': 6672631.0},
#  'Peru': {'Amerindian': 13561143.75,
#   'European': 4520381.25,
#   'Mestizo': 11150273.75,
#   'Total_Population': 30135875.0},
#  'Philippines': {'Chinese': 1385067.78,
#   'Malay': 88182648.66,
#   'Total_Population': 92337852.0},
#  'Pitcairn': {'Bounty': 66.0, 'Total_Population': 66.0},
#  'Poland': {'Byelorussian': 192668.945,
#   'German': 500939.25700000004,
#   'Polish': 37608978.063999996,
#   'Total_Population': 38533789.0,
#   'Ukrainian': 231202.734},
#  'Portugal': {'Total_Population': 10561614.0},
#  'Puerto Rico': {'Amerindian': 14903.156,
#   'Asian': 14903.156,
#   'Black': 298063.12,
#   'Total_Population': 3725789.0,
#   'White': 2988082.778},
#  'Qatar': {'Arab': 679774.0,
#   'Indian': 305898.3,
#   'Iranian': 169943.5,
#   'Pakistani': 305898.3,
#   'Total_Population': 1699435.0},
#  'Reunion': {'Total_Population': 828581.0},
#  'Romania': {'German': 60364.922999999995,
#   'Hungarian': 1328028.3059999999,
#   'Roma': 503041.025,
#   'Romanian': 17928382.130999997,
#   'Russian': 40243.282,
#   'Total_Population': 20121641.0,
#   'Turkish': 40243.282,
#   'Ukrainian': 60364.922999999995},
#  'Russia': {'Bashkir': 1724003.1719999998,
#   'Chuvash': 1580336.2410000002,
#   'Russian': 114646210.938,
#   'Tatar': 5459343.378,
#   'Total_Population': 143666931.0,
#   'Ukrainian': 2873338.62},
#  'Rwanda': {'Hutu': 8412778.4,
#   'Total_Population': 10515973.0,
#   'Tutsi': 1998034.87,
#   'Twa': 105159.73},
#  'Saint Barthelemy': {'Total_Population': 9072.0},
#  'Saint Helena': {'African descent': 2831.5,
#   'Chinese': 1415.75,
#   'Total_Population': 5663.0,
#   'White': 1415.75},
#  'Saint Kitts and Nevis': {'African': 52352.0, 'Total_Population': 52352.0},
#  'Saint Lucia': {'African': 149532.285,
#   'East Indian': 5299.04,
#   'Total_Population': 165595.0},
#  'Saint Martin': {'Total_Population': 37630.0},
#  'Saint Pierre and Miquelon': {'Basques Bretons': 6312.0,
#   'Total_Population': 6312.0},
#  'Saint Vincent and the Grenadines': {'Total_Population': 109991.0},
#  'Samoa': {'Euronesians': 13147.4,
#   'Europeans': 751.28,
#   'Samoan': 173921.32,
#   'Total_Population': 187820.0},
#  'San Marino': {'Total_Population': 32440.0},
#  'Sao Tome and Principe': {'European': 187356.0, 'Total_Population': 187356.0},
#  'Saudi Arabia': {'Afro-Asian': 2713697.7,
#   'Arab': 24423279.3,
#   'Total_Population': 27136977.0},
#  'Senegal': {'Diola': 1215784.35,
#   'European Lebanese': 135087.15,
#   'Fulani': 2296481.55,
#   'Mandingo': 1215784.35,
#   'Serer': 2296481.55,
#   'Total_Population': 13508715.0,
#   'Toucouleur': 1215784.35,
#   'Wolof': 4863137.4},
#  'Serbia': {'Bosniak': 128171.98800000001,
#   'Croat': 78327.326,
#   'Hungarian': 277705.974,
#   'Montenegrin': 64085.994000000006,
#   'Roma': 99689.32399999998,
#   'Serb': 5903032.114000001,
#   'Total_Population': 7120666.0},
#  'Seychelles': {'Seychellois': 90945.0, 'Total_Population': 90945.0},
#  'Sierra Leone': {'African': 5694456.24,
#   'Asian': 57519.76,
#   'Total_Population': 5751976.0},
#  'Singapore': {'Chinese': 3878598.8,
#   'Indian': 324908.8,
#   'Malay': 756428.3,
#   'Total_Population': 5076700.0},
#  'Sint Maarten': {'Total_Population': 37429.0},
#  'Slovakia': {'Czech': 53970.36,
#   'German': 5397.036,
#   'Hungarian': 523512.49199999997,
#   'Polish': 5397.036,
#   'Roma': 91749.612,
#   'Ruthenian': 16191.108,
#   'Slovak': 4625259.852,
#   'Total_Population': 5397036.0,
#   'Ukrainian': 16191.108},
#  'Slovenia': {'Bosniak': 20588.21,
#   'Croat': 61764.63,
#   'Serb': 41176.42,
#   'Slovene': 1873527.11,
#   'Total_Population': 2058821.0},
#  'Solomon Islands': {'Chinese': 1579.3410000000001,
#   'European': 4211.576,
#   'Melanesian': 489595.71,
#   'Micronesian': 7896.705,
#   'Polynesian': 21057.88,
#   'Total_Population': 526447.0},
#  'Somalia': {'Somali': 8190747.05, 'Total_Population': 9636173.0},
#  'South Africa': {'Colored': 4452268.16,
#   'Indian': 1346034.56,
#   'Total_Population': 51770560.0},
#  'South Korea': {'Total_Population': 51141463.0},
#  'South Sudan': {'Total_Population': 8260490.0},
#  'Spain': {'Mediterranean Nordic': 46815916.0, 'Total_Population': 46815916.0},
#  'Sri Lanka': {'Arab': 1418460.61,
#   'Sinhalese': 14995155.02,
#   'Tamil': 3647470.14,
#   'Total_Population': 20263723.0,
#   'Vedda': 202637.23},
#  'Sudan': {'Arab': 24956401.4,
#   'Beja': 2139120.12,
#   'Total_Population': 35652002.0},
#  'Suriname': {'African': 54163.8,
#   'Amerindian': 10832.76,
#   'Chinese': 10832.76,
#   'Creole': 167907.78,
#   'Europeans': 5416.38,
#   'Hindustani': 200406.06,
#   'Javanese': 82870.614,
#   'Total_Population': 541638.0},
#  'Svalbard': {'Norwegian': 1037.088,
#   'Russian Ukrainian': 829.2959999999999,
#   'Total_Population': 1872.0},
#  'Swaziland': {'African': 1157353.56,
#   'European': 35794.44,
#   'Total_Population': 1193148.0},
#  'Sweden': {'Finn': 477794.65,
#   'Swede': 7931391.19,
#   'Total_Population': 9555893.0},
#  'Switzerland': {'French': 1465133.58,
#   'German': 5290760.15,
#   'Italian': 813963.1,
#   'Romansch': 81396.31,
#   'Total_Population': 8139631.0},
#  'Syria': {'Arab': 18841998.0, 'Total_Population': 20866000.0},
#  'Taiwan': {'Chinese': 3264215.08,
#   'Taiwanese': 19585290.48,
#   'Total_Population': 23315822.0},
#  'Tajikistan': {'Kyrgyz': 89772.1,
#   'Russian': 89772.1,
#   'Tajik': 6520718.9,
#   'Total_Population': 8161100.0,
#   'Uzbek': 1248648.3},
#  'Tanzania': {'Bantu': 42682476.85, 'Total_Population': 44928923.0},
#  'Thailand': {'Chinese': 9237432.26,
#   'Thai': 49486244.25,
#   'Total_Population': 65981659.0},
#  'Timor-Leste': {'Total_Population': 1066582.0},
#  'Togo': {'African': 6129243.45,
#   'European Syrian-Lebanese': 61911.55,
#   'Total_Population': 6191155.0},
#  'Tokelau': {'Polynesian': 1313.85, 'Total_Population': 1383.0},
#  'Tonga': {'Total_Population': 103252.0},
#  'Trinidad and Tobago': {'Chinese': 13280.19,
#   'East Indian': 531207.6,
#   'Total_Population': 1328019.0},
#  'Tunisia': {'Arab-Berber': 10763098.92,
#   'European': 109827.54,
#   'Jewish': 109827.54,
#   'Total_Population': 10982754.0},
#  'Turkey': {'Arabic': 1043657.8991999999,
#   'Kurdish': 9052597.8648,
#   'Total_Population': 75627384.0,
#   'Turkish': 63935390.43360001},
#  'Turkmenistan': {'Russian': 201679.8,
#   'Total_Population': 5041995.0,
#   'Turkmen': 4285695.75,
#   'Uzbek': 252099.75},
#  'Turks and Caicos Islands': {'African': 28312.2, 'Total_Population': 31458.0},
#  'Tuvalu': {'Polynesian': 9433.92, 'Total_Population': 9827.0},
#  'Uganda': {'Acholi': 1394272.52,
#   'Arab': 348568.13,
#   'Baganda': 5925658.21,
#   'Bagisu': 1742840.65,
#   'Basogo': 2788545.04,
#   'Batobo': 1045704.39,
#   'Bunyoro': 1045704.39,
#   'Iteso': 2788545.04,
#   'Karamojong': 4182817.56,
#   'Langi': 2091408.78,
#   'Lugbara': 1394272.52,
#   'Rwanda': 2091408.78,
#   'Total_Population': 34856813.0},
#  'Ukraine': {'Belorussian': 273801.822,
#   'Bulgarian': 182534.548,
#   'Crimean Tatar': 228168.185,
#   'Hungarian': 136900.911,
#   'Jewish': 91267.274,
#   'Moldovan': 228168.185,
#   'Polish': 136900.911,
#   'Romanian': 136900.911,
#   'Russian': 7894619.201,
#   'Total_Population': 45633637.0,
#   'Ukrainian': 35502969.585999995},
#  'United Arab Emirates': {'Arab Iranian': 1941553.51,
#   'Emiri': 1603892.03,
#   'South Asian': 4220768.5,
#   'Total_Population': 8441537.0},
#  'United Kingdom': {'African': 1282113.08,
#   'English': 53592326.743999995,
#   'Indian': 1153901.772,
#   'Northern Irish': 1859063.966,
#   'Pakistani': 833373.502,
#   'Scottish': 5513086.244,
#   'Total_Population': 64105654.0,
#   'Welsh': 3141177.046},
#  'United States': {'African': 40973131.696,
#   'Amerindian': 3092913.4432,
#   'Asian': 14125367.580799999,
#   'European': 254958101.97759998,
#   'Total_Population': 318857056.0},
#  'Uruguay': {'African': 131452.56,
#   'European': 2891956.32,
#   'Mestizo': 262905.12,
#   'Total_Population': 3286314.0},
#  'Uzbekistan': {'Karakalpak': 694231.75,
#   'Kazak': 833078.1,
#   'Russian': 1527309.85,
#   'Tajik': 1388463.5,
#   'Tatar': 416539.05,
#   'Total_Population': 27769270.0,
#   'Uzbek': 22215416.0},
#  'Vanuatu': {'French': 9451.96,
#   'Melanesian': 222121.06,
#   'Total_Population': 236299.0},
#  'Venezuela': {'Total_Population': 28946101.0},
#  'Vietnam': {'Khmer': 1331593.5,
#   'Mong': 1065274.8,
#   'Muong': 1331593.5,
#   'Nung': 976501.9000000001,
#   'Tay': 1686685.1,
#   'Thai': 1597912.2,
#   'Total_Population': 88772900.0,
#   'Viet/Kinh': 76078375.3},
#  'Virgin Islands': {'Total_Population': 106405.0},
#  'Wallis and Futuna': {'Polynesian': 12197.0, 'Total_Population': 12197.0},
#  'West Bank': {'Jewish': 474356.27,
#   'Palestinian Arab': 2315974.73,
#   'Total_Population': 2790331.0},
#  'Western Sahara': {'Total_Population': 554795.0},
#  'Yemen': {'Total_Population': 24527000.0},
#  'Zaire': {'Mangbetu-Azande': 27986022.45, 'Total_Population': 62191161.0},
#  'Zambia': {'African': 12876903.396000002,
#   'European': 143511.58800000002,
#   'Total_Population': 13046508.0},
#  'Zimbabwe': {'African': 12800014.22,
#   'Asian': 130612.39,
#   'Total_Population': 13061239.0}}

# %%
# Convert dict to DataFrame, calculate sums of populations by ethnicity, extract row of sums, sort, show top 10
c_ethnic_f = pd.DataFrame.from_dict(c_ethnic, orient='index').fillna(0)
c_ethnic_f.loc['Total']= c_ethnic_f.sum()
top_c_ethnic = c_ethnic_f.drop('Total_Population',1).loc['Total'].sort_values(ascending=False)
top_c_ethnic[0:10]
# Out:
# Han Chinese    1.245059e+09
# Indo-Aryan     8.718156e+08
# European       4.948722e+08
# African        3.183251e+08
# Dravidian      3.027137e+08
# Mestizo        1.577344e+08
# Bengali        1.467769e+08
# Russian        1.318570e+08
# Japanese       1.265342e+08
# Malay          1.219936e+08
# Name: Total, dtype: float64

# %%
# Search data set for longest river
# This search bases country of source
river_size=0.0
river_name=[]
river_country=[]
for child in document.getroot().iterfind('river[length]'):
    if float(child.find('.length').text) > river_size:
        river_size = float(child.find('.length').text)
        river_name = child.find('.name').text
        river_country= country_code[child.find('./source').attrib["country"]]
print "Longest river: " + river_name
print "Length: " + str(river_size)
print "Country of source: " + river_country
# Out:
# Longest river: Amazonas
# Length: 6448.0
# Country of source: Peru

# %%
# Search data set for largest lake
# This search bases country on list of all countries passed by river
lake_size=0.0
lake_name=[]
lake_country=[]
for child in document.getroot().iterfind('lake[area]'):
    if float(child.find('.area').text) > lake_size:
        lake_size = float(child.find('.area').text)
        lake_name = child.find('.name').text
        lake_country = list(map(lambda x: country_code[x], child.attrib["country"].split()))
print "Largest laker: " + lake_name
print "Size: " + str(lake_size)
print "Countries passed: " + str(lake_country)
# Out:
# Largest laker: Caspian Sea
# Size: 386400.0
# Countries passed: ['Russia', 'Azerbaijan', 'Kazakhstan', 'Iran', 'Turkmenistan']

# %%
# Search data set for highest elevalation airport
airport_height=0.0
airport_name=[]
airport_country=[]
for child in document.getroot().iterfind('airport[elevation]'):
    if (child.find('.elevation').text is not None) and (float(child.find('.elevation').text) > airport_height):
        airport_height = float(child.find('.elevation').text)
        airport_name = child.find('.name').text
        airport_country = list(map(lambda x: country_code[x], child.attrib["country"].split()))
        
print "Hightest elevation airport: " + airport_name
print "Elevation: " + str(airport_height)
print "Country: " + str(airport_country)
# Out:
# Hightest elevation airport: El Alto Intl
# Elevation: 4063.0
# Country: ['Bolivia']

# %%
# Created repeatable code to perfom searches based on solution for airport
def search_xml(s_item, s_feat):
    airport_height=0.0
    airport_name=[]
    airport_country=[]
    for child in document.getroot().iterfind((s_item)+'['+s_feat+']'):
        if (child.find('.'+s_feat).text is not None) and (float(child.find('.'+s_feat).text) > airport_height):
            airport_height = float(child.find('.'+s_feat).text)
            airport_name = child.find('.name').text
            airport_country = list(map(lambda x: country_code[x], child.attrib["country"].split()))        
    print "Seach item: " + (s_item).upper()
    print "Seach criteria: " + (s_feat).upper()
    print "Item found: " + airport_name
    print "Criteria: " + str(airport_height)
    print "Country: " + str(airport_country)

# %%
search_xml("airport","elevation")
# Out:
# Seach item: AIRPORT
# Seach criteria: ELEVATION
# Item found: El Alto Intl
# Criteria: 4063.0
# Country: ['Bolivia']

# %%
search_xml("lake","area")
# Out:
# Seach item: LAKE
# Seach criteria: AREA
# Item found: Caspian Sea
# Criteria: 386400.0
# Country: ['Russia', 'Azerbaijan', 'Kazakhstan', 'Iran', 'Turkmenistan']

# %%
search_xml("river","length")
# Out:
# Seach item: RIVER
# Seach criteria: LENGTH
# Item found: Amazonas
# Criteria: 6448.0
# Country: ['Colombia', 'Brazil', 'Peru']
